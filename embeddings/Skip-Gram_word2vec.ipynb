# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
word_count = Counter(int_words)
total_count = len(int_words)
frequency = {word: count/total_count for word, count in word_count.items()}
prob_drop = {word: 1 - np.sqrt(threshold/frequency[word]) for word in word_count}
train_words = [word for word in int_words if random.random() < (1 - prob_drop[word])]
#train_words = # The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(
        softmax_w,
        softmax_b,
        labels,
        embed,
        n_sampled,
        n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6911 0.0616 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5507 0.0585 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5057 0.0580 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5963 0.0609 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5420 0.0577 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5445 0.0575 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5681 0.0580 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5578 0.0608 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5098 0.0614 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4389 0.0643 sec/batch
# Nearest to not: pius, asturias, intra, dmd, grenade, autarky, lg, japonic,
# Nearest to to: jomei, tax, busan, hawaiian, forerunner, reproductive, laughs, aga,
# Nearest to that: cotton, unruly, ratio, curators, oldham, stolen, sul, molds,
# Nearest to of: nvidia, canonization, pskov, privatised, tanka, contested, fz, causing,
# Nearest to many: although, constantinople, utamaro, encodings, syncretism, scully, milkshake, unthinkable,
# Nearest to on: temper, allocated, ribera, homme, mayonnaise, conspirator, warne, morally,
# Nearest to can: exhausted, effortlessly, mercantilists, ganga, disiyyah, unlike, portugu, pass,
# Nearest to s: sophisticated, wrangel, shema, rubber, valladolid, sheep, ariadne, synchronic,
# Nearest to heavy: ifex, culminated, minot, serbo, kuwaiti, penitent, drpg, kinks,
# Nearest to applications: karlheinz, configuration, majesty, sexuality, ungulate, decommissioning, michael, friedman,
# Nearest to hold: sphincter, prominently, predilection, steven, cyborg, hemicellulose, xxvi, mamah,
# Nearest to something: gypsy, bait, nature, ornament, shorted, pleasant, daisuke, communions,
# Nearest to writers: sapphire, pillars, modulate, vox, obed, swooping, summarized, demos,
# Nearest to report: planar, evas, primus, heraclius, morea, me, mujahedin, unilaterally,
# Nearest to accepted: mlb, pisa, suicides, embalmed, orchard, fon, differential, concr,
# Nearest to defense: jahannam, functionaries, decorator, digit, esteban, hatch, submerged, ayman,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4956 0.0649 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3768 0.0634 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3376 0.0646 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2235 0.0643 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1864 0.0673 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1737 0.0670 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0850 0.0680 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0560 0.0672 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9823 0.0667 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9661 0.0689 sec/batch
# Nearest to not: pius, males, grenade, asturias, speculation, intra, receiving, q,
# Nearest to to: ii, reproductive, tax, laughs, hawaiian, busan, devastation, ally,
# Nearest to that: cotton, ratio, unruly, obtained, argued, else, under, happen,
# Nearest to of: nvidia, place, causing, canonization, contested, nothing, unpleasant, conventional,
# Nearest to many: although, encodings, constantinople, numbering, prostitutes, involving, somewhat, developed,
# Nearest to on: allocated, temper, supported, morally, ribera, applied, mayonnaise, matters,
# Nearest to can: unlike, exhausted, pass, program, effortlessly, magnetic, structure, knew,
# Nearest to s: sophisticated, served, rubber, cd, valladolid, shema, wrangel, led,
# Nearest to heavy: ifex, kuwaiti, serbo, at, culminated, minot, squalor, willpower,
# Nearest to applications: configuration, karlheinz, majesty, michael, sexuality, characteristically, plasmids, friedman,
# Nearest to hold: prominently, sphincter, steven, its, predilection, s, dissolving, eminent,
# Nearest to something: nature, gypsy, pleasant, thus, ornament, computations, awry, although,
# Nearest to writers: sapphire, pillars, demos, following, summarized, translate, longer, dave,
# Nearest to report: planar, me, primus, recently, anglo, heraclius, evas, unilaterally,
# Nearest to accepted: differential, mlb, pisa, undisputed, carried, sellers, averages, concr,
# Nearest to defense: digit, jahannam, functionaries, often, committee, submerged, curt, graham,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9247 0.0664 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9107 0.0680 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8855 0.0663 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8361 0.0663 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7917 0.0662 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8168 0.0662 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8122 0.0684 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7856 0.0672 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7793 0.0669 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7796 0.0692 sec/batch
# Nearest to not: pius, intra, asturias, males, grenade, speculation, receiving, do,
# Nearest to to: reproductive, laughs, ii, jomei, devastation, busan, hawaiian, tax,
# Nearest to that: cotton, unruly, ratio, happen, enhanced, else, rebellion, obtained,
# Nearest to of: contested, nvidia, causing, place, unpleasant, canonization, synonyms, integrated,
# Nearest to many: although, numbering, encodings, constantinople, denial, unthinkable, prostitutes, highlights,
# Nearest to on: allocated, temper, homme, endings, morally, supported, matters, conspirator,
# Nearest to can: pass, exhausted, unlike, effortlessly, tunnel, structure, program, magnetic,
# Nearest to s: sophisticated, served, hellenistic, sheep, shema, valladolid, cd, rubber,
# Nearest to heavy: ifex, culminated, kuwaiti, serbo, at, willpower, minot, integrator,
# Nearest to applications: configuration, karlheinz, plasmids, majesty, sexuality, friedman, michael, dread,
# Nearest to hold: prominently, steven, sphincter, predilection, its, clients, emphasise, dissolving,
# Nearest to something: nature, gypsy, ornament, multilateral, mikhail, rainbow, pleasant, bait,
# Nearest to writers: sapphire, pillars, demos, translate, actor, modulate, following, stimulated,
# Nearest to report: planar, heraclius, unilaterally, evas, anglo, surveillance, morea, primus,
# Nearest to accepted: differential, pisa, mlb, oxidation, undisputed, suicides, embalmed, averages,
# Nearest to defense: digit, jahannam, submerged, bolster, graham, committee, curt, boosted,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7716 0.0673 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7710 0.0680 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7301 0.0689 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7165 0.0673 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7382 0.0678 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6990 0.0695 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7248 0.0682 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7254 0.0668 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7012 0.0700 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6705 0.0745 sec/batch
# Nearest to not: pius, intra, asturias, do, epithelial, avoiding, toilets, grenade,
# Nearest to to: reproductive, laughs, devastation, busan, jomei, bulbs, rag, ally,
# Nearest to that: enhanced, happen, unruly, curators, cotton, ratio, pull, rebellion,
# Nearest to of: contested, nvidia, causing, place, synonyms, overcoming, canonization, unpleasant,
# Nearest to many: although, numbering, denial, storage, voodoo, toil, unthinkable, syncretism,
# Nearest to on: conspirator, warne, temper, endings, supported, matters, homme, allocated,
# Nearest to can: pass, unlike, exhausted, tunnel, structure, rainey, magnetic, effortlessly,
# Nearest to s: served, sophisticated, hellenistic, sheep, ariadne, shema, led, rubber,
# Nearest to heavy: kuwaiti, serbo, ifex, culminated, integrator, at, willpower, minot,
# Nearest to applications: configuration, karlheinz, plasmids, friedman, sexuality, dread, majesty, dostoyevsky,
# Nearest to hold: prominently, steven, sphincter, cyborg, predilection, its, freemasonry, hemicellulose,
# Nearest to something: nature, multilateral, rainbow, ornament, gypsy, bait, embodied, awry,
# Nearest to writers: sapphire, pillars, demos, modulate, actor, translate, plumb, multiplicity,
# Nearest to report: unilaterally, planar, evas, heraclius, morea, mujahedin, surveillance, primus,
# Nearest to accepted: differential, pisa, embalmed, mlb, sellers, suicides, concr, orchard,
# Nearest to defense: digit, jahannam, curt, bolster, boosted, functionaries, graham, submerged,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6690 0.0683 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6701 0.0729 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6358 0.0709 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6220 0.0690 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6242 0.0670 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6298 0.0685 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5999 0.0535 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5402 0.0673 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4765 0.0676 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4953 0.0668 sec/batch
# Nearest to not: do, intra, toilets, dmd, pius, some, epithelial, asturias,
# Nearest to to: reproductive, jomei, rag, ninds, busan, devastation, laughs, beryl,
# Nearest to that: happen, unruly, argued, curators, or, ratio, enhanced, obtained,
# Nearest to of: contested, nvidia, place, synonyms, causing, until, grieved, overcoming,
# Nearest to many: although, denial, syncretism, toil, interpersonal, storage, numbering, unthinkable,
# Nearest to on: warne, conspirator, endings, temper, matters, handsome, supported, allocated,
# Nearest to can: pass, unlike, structure, magnetic, program, determining, effortlessly, modules,
# Nearest to s: served, sophisticated, hellenistic, ariadne, shema, governor, sheep, roche,
# Nearest to heavy: kuwaiti, ifex, serbo, culminated, integrator, at, there, willpower,
# Nearest to applications: configuration, plasmids, karlheinz, elementary, data, friedman, dread, dostoyevsky,
# Nearest to hold: prominently, steven, cyborg, sphincter, bmc, predilection, wholesale, hemicellulose,
# Nearest to something: nature, bait, multilateral, ornament, rainbow, palmer, embodied, glad,
# Nearest to writers: sapphire, demos, pillars, modulate, multiplicity, plumb, dave, workin,
# Nearest to report: unilaterally, planar, evas, mujahedin, morea, partakers, anglo, indepth,
# Nearest to accepted: embalmed, pisa, differential, undisputed, mlb, sellers, concr, orchard,
# Nearest to defense: digit, curt, jahannam, bolster, boosted, committee, functionaries, ayman,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5004 0.0676 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4851 0.0668 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4796 0.0662 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5186 0.0675 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5033 0.0695 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.5051 0.0712 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4603 0.0687 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3810 0.0681 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4515 0.0679 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4137 0.0684 sec/batch
# Nearest to not: do, some, pius, that, epithelial, intra, toilets, avoiding,
# Nearest to to: reproductive, beryl, rag, ninds, jomei, eschews, busan, treat,
# Nearest to that: happen, unruly, argued, not, else, obtained, ppg, omitted,
# Nearest to of: synonyms, contested, place, causing, nvidia, nile, overcoming, privatised,
# Nearest to many: although, interpersonal, syncretism, somewhat, toil, storage, denial, prostitutes,
# Nearest to on: warne, conspirator, supported, allocated, mayonnaise, matters, endings, grooved,
# Nearest to can: pass, structure, determining, magnetic, unlike, program, require, modules,
# Nearest to s: served, hellenistic, ariadne, sophisticated, shema, talkies, sheep, governor,
# Nearest to heavy: kuwaiti, ifex, serbo, at, integrator, there, imine, culminated,
# Nearest to applications: configuration, plasmids, elementary, data, karlheinz, communication, application, dread,
# Nearest to hold: prominently, sphincter, bmc, hemicellulose, cyborg, publicizing, steven, leaded,
# Nearest to something: nature, bait, ornament, awry, overvalued, communions, palmer, thus,
# Nearest to writers: sapphire, dave, demos, modulate, plumb, bri, workin, pillars,
# Nearest to report: unilaterally, evas, planar, partakers, indepth, mujahedin, morea, primus,
# Nearest to accepted: embalmed, pisa, differential, confronted, concr, undisputed, paraphrase, factorials,
# Nearest to defense: digit, curt, boosted, bolster, jahannam, committee, camacho, ayman,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4414 0.0677 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4347 0.0665 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4281 0.0669 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3935 0.0678 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4325 0.0662 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4454 0.0659 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3915 0.0664 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3569 0.0668 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4256 0.0665 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3779 0.0666 sec/batch
# Nearest to not: do, some, epithelial, pius, intra, that, dmd, avoiding,
# Nearest to to: reproductive, rag, ninds, beryl, catastrophic, helpers, laughs, devastation,
# Nearest to that: argued, else, unruly, happen, omitted, give, not, obtained,
# Nearest to of: nvidia, synonyms, place, contested, nile, inductive, procuring, syntactic,
# Nearest to many: although, interpersonal, somewhat, syncretism, pounded, denial, reused, utamaro,
# Nearest to on: warne, conspirator, grooved, ribera, temper, allocated, mooney, opened,
# Nearest to can: structure, determining, unlike, pass, magnetic, modules, require, program,
# Nearest to s: served, hellenistic, sophisticated, ariadne, shema, talkies, sheep, wrangel,
# Nearest to heavy: integrator, kuwaiti, ifex, at, imine, synthesize, processed, there,
# Nearest to applications: configuration, elementary, plasmids, data, karlheinz, communication, dread, application,
# Nearest to hold: sphincter, cyborg, prominently, bmc, hemicellulose, leaded, publicizing, freemasonry,
# Nearest to something: nature, bait, thus, overvalued, ornament, communions, what, identity,
# Nearest to writers: sapphire, workin, demos, dave, plumb, vigen, multiplicity, bri,
# Nearest to report: unilaterally, indepth, planar, evas, primus, partakers, surveillance, mujahedin,
# Nearest to accepted: embalmed, pisa, churned, confronted, factorials, extragalactic, undisputed, paraphrase,
# Nearest to defense: boosted, bolster, committee, digit, curt, jahannam, ayman, gambia,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3616 0.0671 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3972 0.0664 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3634 0.0681 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3633 0.0675 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3715 0.0681 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3495 0.0676 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3613 0.0677 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3803 0.0686 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3285 0.0684 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3248 0.0681 sec/batch
# Nearest to not: do, pius, some, that, epithelial, intra, dmd, toilets,
# Nearest to to: reproductive, decontamination, rag, catastrophic, ninds, devastation, restrictive, palliative,
# Nearest to that: happen, unruly, not, argued, else, proudhon, especial, omitted,
# Nearest to of: synonyms, contested, place, procuring, nvidia, nile, decss, canonization,
# Nearest to many: although, somewhat, interpersonal, denial, pounded, syncretism, nonetheless, utamaro,
# Nearest to on: warne, conspirator, supported, ribera, grooved, mooney, disappointed, matters,
# Nearest to can: determining, structure, unlike, pass, require, oscillates, modules, offbeat,
# Nearest to s: served, hellenistic, sophisticated, shema, ariadne, talkies, wrangel, casson,
# Nearest to heavy: kuwaiti, at, integrator, imine, ifex, synthesize, there, willpower,
# Nearest to applications: configuration, elementary, karlheinz, data, plasmids, communication, dread, dostoyevsky,
# Nearest to hold: sphincter, cyborg, prominently, bmc, publicizing, leaded, its, freemasonry,
# Nearest to something: nature, bait, ornament, identity, communions, overvalued, what, thus,
# Nearest to writers: sapphire, workin, dave, plumb, vigen, multiplicity, hazy, demos,
# Nearest to report: unilaterally, indepth, evas, partakers, planar, morea, polygram, surveillance,
# Nearest to accepted: churned, pisa, confronted, embalmed, factorials, paraphrase, undisputed, vandals,
# Nearest to defense: committee, boosted, bolster, curt, ayman, camacho, repatriation, gambia,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3439 0.0698 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3089 0.0687 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3751 0.0679 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3732 0.0678 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3871 0.0681 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3040 0.0682 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2967 0.0676 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3377 0.0672 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2278 0.0680 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2927 0.0680 sec/batch
# Nearest to not: do, pius, some, japonic, toilets, epithelial, geopolitical, grenade,
# Nearest to to: rag, reproductive, decontamination, jomei, beryl, devastation, catastrophic, palliative,
# Nearest to that: happen, proudhon, unruly, argued, omitted, scruple, midler, obtained,
# Nearest to of: contested, decss, nvidia, synonyms, place, nile, requirements, the,
# Nearest to many: although, somewhat, interpersonal, utamaro, denial, nonetheless, syncretism, metallica,
# Nearest to on: conspirator, mooney, warne, disappointed, opened, grooved, supported, ribera,
# Nearest to can: determining, structure, unlike, oscillates, shortcut, submissions, effortlessly, modules,
# Nearest to s: sophisticated, served, shema, hellenistic, talkies, casson, roche, agriculture,
# Nearest to heavy: kuwaiti, at, imine, integrator, ifex, archdruid, contractor, willpower,
# Nearest to applications: configuration, elementary, karlheinz, plasmids, data, application, communication, dread,
# Nearest to hold: sphincter, cyborg, bmc, leaded, prominently, tinted, its, freemasonry,
# Nearest to something: nature, bait, ornament, norms, glad, overvalued, what, thus,
# Nearest to writers: workin, sapphire, plumb, multiplicity, vigen, hazy, classmates, dave,
# Nearest to report: unilaterally, indepth, evas, partakers, primus, polygram, mukti, surveillance,
# Nearest to accepted: churned, embalmed, confronted, pisa, factorials, paraphrase, undisputed, extragalactic,
# Nearest to defense: committee, boosted, bolster, curt, ayman, repatriation, camacho, gambia,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2999 0.0686 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2796 0.0679 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3468 0.0327 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2236 0.0675 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2371 0.0671 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2190 0.0674 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2322 0.0674 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2083 0.0670 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2120 0.0682 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1675 0.0675 sec/batch
# Nearest to not: do, some, pius, grenade, geopolitical, toilets, dmd, japonic,
# Nearest to to: rag, reproductive, defend, catastrophic, devastation, carry, ninds, decontamination,
# Nearest to that: happen, proudhon, unruly, else, marginalised, omitted, argued, especial,
# Nearest to of: nile, subarctic, place, contested, the, synonyms, melaka, until,
# Nearest to many: although, somewhat, interpersonal, syncretism, denial, pounded, utamaro, arterial,
# Nearest to on: conspirator, grooved, disappointed, allocated, opened, warne, mooney, spectacular,
# Nearest to can: determining, structure, unlike, oscillates, pass, clearance, effortlessly, extramarital,
# Nearest to s: sophisticated, talkies, served, shema, casson, hellenistic, ariadne, satisfactory,
# Nearest to heavy: at, contractor, imine, kuwaiti, integrator, willpower, ifex, torsional,
# Nearest to applications: configuration, elementary, data, karlheinz, plasmids, application, page, deflate,
# Nearest to hold: cyborg, sphincter, publicizing, bmc, freemasonry, tinted, prominently, xxvi,
# Nearest to something: nature, bait, overvalued, what, ornament, glad, thus, manors,
# Nearest to writers: workin, sapphire, vigen, plumb, hazy, classmates, multiplicity, translate,
# Nearest to report: indepth, evas, partakers, unilaterally, kakatiya, mukti, polygram, wert,
# Nearest to accepted: churned, pisa, factorials, embalmed, paraphrase, confronted, vandals, undisputed,
# Nearest to defense: committee, bolster, boosted, ayman, curt, repatriation, camacho, sensuous,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2558 0.0682 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2225 0.0679 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2193 0.0683 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1078 0.0681 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1765 0.0686 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1589 0.0684 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1915 0.0688 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.2003 0.0681 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1855 0.0679 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1704 0.0680 sec/batch
# Nearest to not: do, some, toilets, pius, japonic, that, lest, sinless,
# Nearest to to: rag, reproductive, decontamination, carry, ninds, defend, jomei, devastation,
# Nearest to that: happen, else, especial, scruple, proudhon, unruly, marginalised, omitted,
# Nearest to of: procuring, astrid, the, requirements, melaka, decss, nvidia, kennedys,
# Nearest to many: although, somewhat, syncretism, utamaro, pounded, interpersonal, prostitutes, metallica,
# Nearest to on: conspirator, grooved, opened, disappointed, mooney, farnham, allocated, uris,
# Nearest to can: determining, structure, oscillates, pass, unlike, clearance, require, submissions,
# Nearest to s: sophisticated, talkies, shema, served, casson, hellenistic, vanier, satisfactory,
# Nearest to heavy: contractor, at, torsional, imine, willpower, cockpit, kuwaiti, integrator,
# Nearest to applications: configuration, karlheinz, elementary, page, decommissioning, dostoyevsky, communication, bankers,
# Nearest to hold: publicizing, bmc, freemasonry, sphincter, cyborg, foils, tinted, prominently,
# Nearest to something: nature, bait, thus, glad, ornament, overvalued, what, manors,
# Nearest to writers: workin, classmates, sapphire, hazy, plumb, vigen, multiplicity, bri,
# Nearest to report: indepth, partakers, evas, kakatiya, unilaterally, polygram, mukti, planar,
# Nearest to accepted: factorials, paraphrase, churned, pisa, confronted, undisputed, embalmed, vandals,
# Nearest to defense: bolster, committee, boosted, curt, ayman, repatriation, camacho, boost,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1828 0.0685 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2199 0.0677 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1749 0.0676 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1317 0.0674 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1659 0.0677 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1881 0.0679 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1834 0.0681 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1674 0.0673 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1453 0.0675 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1758 0.0674 sec/batch
# Nearest to not: do, some, pius, japonic, that, sinless, indole, toilets,
# Nearest to to: rag, decontamination, ninds, defend, reproductive, differentia, carry, multiplicity,
# Nearest to that: else, happen, unruly, scruple, proudhon, omitted, especial, not,
# Nearest to of: the, procuring, astrid, nvidia, lans, seimas, kennedys, cassian,
# Nearest to many: although, syncretism, somewhat, utamaro, interpersonal, similarities, thrillers, denial,
# Nearest to on: conspirator, disappointed, festal, opened, msi, mooney, matters, grooved,
# Nearest to can: determining, structure, oscillates, require, extramarital, euclidean, unlike, clearance,
# Nearest to s: sophisticated, talkies, shema, hellenistic, the, satisfactory, has, casson,
# Nearest to heavy: willpower, kuwaiti, contractor, torsional, imine, cockpit, at, archdruid,
# Nearest to applications: configuration, karlheinz, elementary, splay, dostoyevsky, decommissioning, data, deflate,
# Nearest to hold: publicizing, freemasonry, bmc, sphincter, its, foils, leaded, tariffs,
# Nearest to something: nature, what, thus, norms, bait, glad, manors, communions,
# Nearest to writers: workin, hazy, classmates, sapphire, plumb, multiplicity, vigen, translate,
# Nearest to report: indepth, evas, partakers, polygram, kakatiya, unilaterally, mukti, planar,
# Nearest to accepted: paraphrase, churned, factorials, undisputed, pisa, conforms, vandals, confronted,
# Nearest to defense: committee, bolster, boosted, ayman, curt, repatriation, camacho, interim,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2031 0.0688 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1406 0.0677 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1979 0.0672 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1809 0.0677 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1362 0.0684 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1156 0.0683 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1918 0.0681 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1360 0.0681 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1809 0.0682 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2105 0.0675 sec/batch
# Nearest to not: do, pius, japonic, some, that, sinless, geopolitical, lest,
# Nearest to to: defend, churchill, normandy, devastation, rag, kazakhstani, decontamination, farber,
# Nearest to that: proudhon, especial, marginalised, unruly, happen, else, scruple, omitted,
# Nearest to of: the, in, habibullah, procuring, an, haakon, seimas, until,
# Nearest to many: although, syncretism, somewhat, elias, similarities, utamaro, interpersonal, developed,
# Nearest to on: conspirator, disappointed, lai, opened, matters, the, undertook, hijacked,
# Nearest to can: oscillates, structure, determining, clearance, require, repetition, unlike, submissions,
# Nearest to s: sophisticated, the, casson, talkies, hellenistic, shema, served, agnetha,
# Nearest to heavy: torsional, willpower, kuwaiti, chaplain, imine, contractor, melachim, cockpit,
# Nearest to applications: configuration, karlheinz, elementary, dostoyevsky, splay, deflate, decommissioning, freedesktop,
# Nearest to hold: its, publicizing, freemasonry, bmc, sinking, foils, cyborg, tariffs,
# Nearest to something: nature, what, bait, norms, gypsy, glad, ornament, thus,
# Nearest to writers: workin, classmates, plumb, hazy, vigen, sapphire, multiplicity, mattie,
# Nearest to report: indepth, evas, unilaterally, partakers, journal, mukti, polygram, maharaja,
# Nearest to accepted: paraphrase, churned, undisputed, factorials, vandals, pisa, bogot, supported,
# Nearest to defense: committee, bolster, curt, ayman, boosted, interim, repatriation, camacho,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2338 0.0687 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1168 0.0674 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1449 0.0675 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1831 0.0708 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0348 0.0747 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1541 0.0685 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1389 0.0679 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1152 0.0692 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1895 0.0150 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1121 0.0672 sec/batch
# Nearest to not: do, evaluator, some, that, lest, i, intra, toilets,
# Nearest to to: rag, defend, carry, ninds, given, slowdown, reproductive, checking,
# Nearest to that: proudhon, happen, marginalised, scruple, especial, omitted, tni, obtained,
# Nearest to of: the, in, for, an, astrid, seimas, lans, procuring,
# Nearest to many: although, utamaro, elias, interpersonal, somewhat, similarities, syncretism, developed,
# Nearest to on: conspirator, lai, the, grooved, disappointed, opened, farnham, uris,
# Nearest to can: clearance, structure, determining, pass, unlike, oscillates, extramarital, repetition,
# Nearest to s: sophisticated, talkies, the, casson, agnetha, soroban, its, sgi,
# Nearest to heavy: torsional, chaplain, willpower, kuwaiti, cockpit, contractor, imine, melachim,
# Nearest to applications: configuration, karlheinz, elementary, dostoyevsky, deflate, decommissioning, freedesktop, application,
# Nearest to hold: publicizing, freemasonry, bmc, foils, emphasise, tariffs, cyborg, clients,
# Nearest to something: nature, what, norms, bait, manors, glad, gypsy, ornament,
# Nearest to writers: classmates, workin, hazy, plumb, multiplicity, vigen, mattie, cultural,
# Nearest to report: indepth, journal, evas, partakers, unilaterally, mukti, polygram, policymakers,
# Nearest to accepted: paraphrase, churned, undisputed, embalmed, factorials, pisa, vandals, irulan,
# Nearest to defense: curt, ayman, bolster, boosted, committee, bureau, jury, camacho,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0838 0.0684 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0446 0.0669 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0936 0.0669 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0173 0.0670 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0716 0.0673 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0432 0.0675 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1093 0.0673 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1066 0.0675 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1293 0.0681 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0400 0.0680 sec/batch
# Nearest to not: do, that, some, japonic, evaluator, sinless, i, intra,
# Nearest to to: rag, devastation, defend, carry, but, given, ninds, catastrophic,
# Nearest to that: especial, proudhon, not, marginalised, happen, obtained, scruple, else,
# Nearest to of: the, in, an, a, for, seimas, until, lans,
# Nearest to many: although, utamaro, interpersonal, somewhat, similarities, elias, syncretism, rko,
# Nearest to on: conspirator, lai, disappointed, the, farnham, grooved, hijacked, opened,
# Nearest to can: structure, clearance, determining, unlike, pass, repetition, extramarital, semantic,
# Nearest to s: sophisticated, the, its, casson, talkies, soroban, integral, has,
# Nearest to heavy: torsional, chaplain, cockpit, ascendancy, willpower, kuwaiti, contractor, culminated,
# Nearest to applications: karlheinz, configuration, dostoyevsky, decommissioning, elementary, deflate, splay, bankers,
# Nearest to hold: publicizing, freemasonry, bmc, foils, tariffs, memberships, prominently, alterations,
# Nearest to something: nature, gypsy, manors, what, norms, bait, glad, pleasant,
# Nearest to writers: classmates, hazy, workin, cultural, vigen, plumb, multiplicity, mattie,
# Nearest to report: indepth, journal, evas, partakers, kakatiya, polygram, policymakers, entitled,
# Nearest to accepted: paraphrase, undisputed, churned, woodworth, factorials, embalmed, pisa, irulan,
# Nearest to defense: curt, bolster, boosted, ayman, committee, enemy, airborne, bureau,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0420 0.0692 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0239 0.0691 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0032 0.0684 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0422 0.0679 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0627 0.0679 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0526 0.0685 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0676 0.0675 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1150 0.0678 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0546 0.0676 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0494 0.0677 sec/batch
# Nearest to not: do, that, some, i, implying, evaluator, japonic, sinless,
# Nearest to to: given, checking, but, carry, devastation, differentia, rag, defend,
# Nearest to that: proudhon, not, especial, cannot, scruple, happen, intimately, else,
# Nearest to of: the, a, in, lans, an, for, astrid, emoticons,
# Nearest to many: although, utamaro, interpersonal, somewhat, similarities, syncretism, developed, metallica,
# Nearest to on: disappointed, the, lai, grooved, conspirator, farnham, date, uris,
# Nearest to can: determining, structure, unlike, repetition, pass, semantic, clearance, oscillates,
# Nearest to s: the, integral, sophisticated, talkies, casson, agnetha, soroban, prentice,
# Nearest to heavy: torsional, chaplain, imine, lsa, culminated, willpower, cockpit, kuwaiti,
# Nearest to applications: karlheinz, elementary, decommissioning, dostoyevsky, configuration, splay, dxf, deflate,
# Nearest to hold: publicizing, freemasonry, tinted, foils, prominently, bmc, plausibility, alterations,
# Nearest to something: nature, what, norms, bait, inverts, manors, gypsy, thus,
# Nearest to writers: classmates, workin, vigen, hazy, cultural, plumb, alumni, mattie,
# Nearest to report: journal, indepth, evas, kakatiya, psychiatry, polygram, overview, policymakers,
# Nearest to accepted: paraphrase, undisputed, churned, factorials, embalmed, woodworth, pisa, ascendancy,
# Nearest to defense: curt, ayman, boosted, bolster, bureau, committee, airborne, reconnaissance,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0629 0.0688 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0565 0.0677 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0877 0.0675 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0522 0.0675 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0480 0.0679 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0601 0.0674 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0598 0.0670 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0711 0.0674 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0757 0.0675 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0594 0.0685 sec/batch
# Nearest to not: do, that, i, sinless, pius, some, japonic, but,
# Nearest to to: defend, given, churchill, carry, he, eutropius, apostle, but,
# Nearest to that: not, especial, proudhon, happen, unruly, cannot, marginalised, maimon,
# Nearest to of: the, in, a, for, and, an, until, emoticons,
# Nearest to many: although, somewhat, utamaro, elias, interpersonal, similarities, metallica, rko,
# Nearest to on: conspirator, the, lai, farnham, disappointed, date, uphold, undertook,
# Nearest to can: structure, determining, clearance, pass, emotive, repetition, unlike, extramarital,
# Nearest to s: the, sophisticated, integral, casson, its, talkies, agnetha, hellenistic,
# Nearest to heavy: torsional, chaplain, lsa, culminated, melachim, archdruid, imine, categorize,
# Nearest to applications: karlheinz, configuration, elementary, freedesktop, decommissioning, dostoyevsky, splay, dxf,
# Nearest to hold: freemasonry, publicizing, tariffs, rabbinate, emphasise, alterations, bmc, restricted,
# Nearest to something: nature, what, norms, pleasant, gypsy, manors, blatantly, inverts,
# Nearest to writers: classmates, workin, vigen, hazy, plumb, mattie, multiplicity, satirists,
# Nearest to report: journal, indepth, evas, overview, kakatiya, entitled, polygram, ioc,
# Nearest to accepted: paraphrase, undisputed, churned, factorials, ascendancy, pisa, woodworth, surprisingly,
# Nearest to defense: curt, ayman, bureau, committee, boosted, interim, bolster, terrell,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0772 0.0692 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9792 0.0681 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0253 0.0677 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0818 0.0683 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0729 0.0679 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1088 0.0680 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1260 0.0678 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0312 0.0674 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0367 0.0678 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0611 0.0676 sec/batch
# Nearest to not: do, that, i, sinless, japonic, some, evaluator, pius,
# Nearest to to: checking, given, slowdown, carry, would, jomei, disassembled, defend,
# Nearest to that: not, happen, cannot, proudhon, especial, scruple, prescriptions, omitted,
# Nearest to of: the, in, for, a, an, lans, and, emoticons,
# Nearest to many: although, somewhat, metallica, developed, interpersonal, elias, impersonated, similarities,
# Nearest to on: the, conspirator, disappointed, lai, date, farnham, msi, arrowhead,
# Nearest to can: structure, determining, unlike, shortcut, birthdays, repetition, clearance, emotive,
# Nearest to s: the, casson, integral, sophisticated, talkies, its, agnetha, rafik,
# Nearest to heavy: torsional, lsa, chaplain, culminated, tending, archdruid, categorize, melachim,
# Nearest to applications: karlheinz, freedesktop, configuration, dostoyevsky, decommissioning, elementary, splay, application,
# Nearest to hold: freemasonry, tariffs, its, bmc, rabbinate, foils, memberships, alterations,
# Nearest to something: what, nature, norms, pleasant, blatantly, gypsy, manors, bait,
# Nearest to writers: classmates, workin, alumni, vigen, novelists, fiction, hazy, satirists,
# Nearest to report: journal, indepth, overview, policymakers, evas, kakatiya, ioc, polygram,
# Nearest to accepted: paraphrase, undisputed, ascendancy, churned, woodworth, irulan, pisa, bogot,
# Nearest to defense: curt, bureau, ayman, committee, bolster, defenses, jury, interim,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9884 0.0693 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0197 0.0679 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0294 0.0679 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0359 0.0673 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0872 0.0674 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0576 0.0646 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0121 0.0677 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9848 0.0672 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0205 0.0670 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9721 0.0670 sec/batch
# Nearest to not: do, that, sinless, i, some, but, evaluator, japonic,
# Nearest to to: defend, checking, he, carry, that, would, devastation, rag,
# Nearest to that: not, cannot, happen, prescriptions, proudhon, maimon, scruple, evidence,
# Nearest to of: the, in, a, for, an, emoticons, and, from,
# Nearest to many: although, similarities, interpersonal, utamaro, metallica, somewhat, developed, rko,
# Nearest to on: conspirator, the, lai, disappointed, date, farnham, undertook, grooved,
# Nearest to can: determining, structure, unlike, clearance, allosteric, birthdays, oscillates, pass,
# Nearest to s: integral, sophisticated, the, casson, agnetha, its, talkies, rafik,
# Nearest to heavy: torsional, chaplain, lsa, ascendancy, metal, archdruid, tending, culminated,
# Nearest to applications: karlheinz, freedesktop, configuration, decommissioning, application, dostoyevsky, dxf, elementary,
# Nearest to hold: rabbinate, freemasonry, nicaea, plausibility, amass, memberships, xxvi, bmc,
# Nearest to something: what, nature, norms, pleasant, blatantly, glad, manors, overvalued,
# Nearest to writers: classmates, novelists, hazy, vigen, alumni, satirists, workin, essayists,
# Nearest to report: journal, indepth, overview, evas, entitled, psychiatry, policymakers, ioc,
# Nearest to accepted: paraphrase, undisputed, churned, irulan, woodworth, ascendancy, factorials, surprisingly,
# Nearest to defense: curt, bureau, defenses, airborne, ayman, bolster, boosted, committee,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0005 0.0686 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9704 0.0675 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0315 0.0674 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9874 0.0675 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0382 0.0680 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0223 0.0682 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8955 0.0680 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9682 0.0683 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9166 0.0683 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9947 0.0680 sec/batch
# Nearest to not: do, that, some, sinless, but, i, japonic, toilets,
# Nearest to to: defend, but, checking, carry, slowdown, given, gibbous, voles,
# Nearest to that: not, cannot, happen, scruple, especial, marginalised, prescriptions, evidence,
# Nearest to of: the, in, a, for, and, lans, an, emoticons,
# Nearest to many: although, metallica, similarities, rko, interpersonal, utamaro, developed, somewhat,
# Nearest to on: the, conspirator, lai, grooved, farnham, disappointed, date, undertook,
# Nearest to can: structure, determining, oint, unlike, addressable, clearance, semantic, pass,
# Nearest to s: the, integral, its, talkies, sophisticated, casson, has, soroban,
# Nearest to heavy: torsional, chaplain, ascendancy, lsa, metal, culminated, tending, metalworking,
# Nearest to applications: karlheinz, configuration, decommissioning, freedesktop, dostoyevsky, dxf, application, elementary,
# Nearest to hold: tinted, foils, prominently, freemasonry, numeric, taliesin, converters, bmc,
# Nearest to something: what, nature, glad, blatantly, norms, bait, pleasant, manors,
# Nearest to writers: classmates, novelists, alumni, satirists, hazy, poets, mattie, workin,
# Nearest to report: journal, overview, indepth, evas, entitled, kakatiya, psychiatry, reports,
# Nearest to accepted: paraphrase, undisputed, churned, provers, factorials, surprisingly, ascendancy, irulan,
# Nearest to defense: curt, bureau, defenses, terrell, ayman, bolster, airborne, boosted,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0147 0.0694 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9860 0.0685 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9796 0.0683 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9796 0.0679 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0420 0.0683 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9421 0.0680 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0017 0.0676 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9781 0.0678 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0115 0.0682 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0005 0.0678 sec/batch
# Nearest to not: do, that, but, some, sinless, i, intra, implying,
# Nearest to to: given, he, checking, but, that, defend, before, voles,
# Nearest to that: cannot, not, happen, to, prescriptions, proudhon, scruple, it,
# Nearest to of: the, in, a, for, and, an, lans, emoticons,
# Nearest to many: although, similarities, utamaro, metallica, interpersonal, rko, developed, flaherty,
# Nearest to on: the, lai, disappointed, a, conspirator, farnham, date, uphold,
# Nearest to can: determining, structure, oint, shortcut, emotive, repetition, semantic, addressable,
# Nearest to s: the, integral, its, in, has, sophisticated, talkies, agnetha,
# Nearest to heavy: torsional, culminated, lsa, chaplain, metal, metalworking, ascendancy, archdruid,
# Nearest to applications: karlheinz, configuration, decommissioning, freedesktop, dxf, dostoyevsky, elementary, application,
# Nearest to hold: freemasonry, prominently, bmc, foils, memberships, rabbinate, alterations, tinted,
# Nearest to something: what, nature, norms, pleasant, blatantly, inverts, manors, glad,
# Nearest to writers: novelists, classmates, alumni, poets, satirists, hazy, fiction, essayists,
# Nearest to report: journal, overview, indepth, evas, entitled, psychiatry, kakatiya, reports,
# Nearest to accepted: paraphrase, undisputed, provers, supported, churned, ascendancy, surprisingly, factorials,
# Nearest to defense: curt, bureau, defenses, terrell, offense, ayman, bolster, jury,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0069 0.0684 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9708 0.0677 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9777 0.0674 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0045 0.0678 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0179 0.0675 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9831 0.0679 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9781 0.0683 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9877 0.0684 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9549 0.0679 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0447 0.0685 sec/batch
# Nearest to not: do, that, some, but, sinless, i, japonic, occurrences,
# Nearest to to: that, he, given, defend, checking, slowdown, would, carry,
# Nearest to that: not, cannot, to, it, prescriptions, especial, happen, surely,
# Nearest to of: the, in, a, for, and, an, from, lans,
# Nearest to many: although, similarities, developed, prefigured, interpersonal, least, columbus, metallica,
# Nearest to on: the, lai, conspirator, uphold, undertook, date, msi, april,
# Nearest to can: determining, shortcut, pass, structure, oint, unlike, emotive, repetition,
# Nearest to s: the, its, in, has, integral, casson, refrained, sophisticated,
# Nearest to heavy: torsional, metal, culminated, lsa, chaplain, categorize, metalworking, archdruid,
# Nearest to applications: karlheinz, configuration, dxf, freedesktop, dostoyevsky, decommissioning, elementary, lockyer,
# Nearest to hold: foils, bmc, freemasonry, rabbinate, memberships, numeric, converters, mishandling,
# Nearest to something: what, pleasant, blatantly, nature, norms, lunches, bait, glad,
# Nearest to writers: novelists, classmates, alumni, satirists, poets, essayists, fiction, hazy,
# Nearest to report: journal, overview, indepth, reports, ioc, psychiatry, policymakers, evas,
# Nearest to accepted: paraphrase, undisputed, vandals, supported, ascendancy, provers, churned, surprisingly,
# ...
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8737 0.0689 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7654 0.0694 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8228 0.0686 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7749 0.0685 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8251 0.0681 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8720 0.0682 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8452 0.0685 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8364 0.0681 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8541 0.0675 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9009 0.0678 sec/batch
# Nearest to not: do, to, that, but, or, some, for, the,
# Nearest to to: that, a, the, and, not, in, of, before,
# Nearest to that: to, it, the, a, not, cannot, is, had,
# Nearest to of: the, in, a, and, from, for, an, s,
# Nearest to many: although, as, are, least, developed, some, various, examples,
# Nearest to on: the, in, a, of, and, to, holiday, when,
# Nearest to can: or, it, cannot, determining, infantryman, is, a, if,
# Nearest to s: the, in, of, was, has, its, two, zero,
# Nearest to heavy: metal, torsional, metalworking, tending, melachim, propelled, widget, processed,
# Nearest to applications: karlheinz, dostoyevsky, dxf, freedesktop, decommissioning, application, developers, methodology,
# Nearest to hold: down, robes, humid, subterfuge, umbrella, montenegrins, saadia, tinted,
# Nearest to something: anything, unseemly, what, pleasant, blatantly, insisted, despised, philosophy,
# Nearest to writers: novelists, alumni, essayists, poets, births, satirists, fiction, authors,
# Nearest to report: journal, reports, overview, sofa, forecasts, indepth, morea, summary,
# Nearest to accepted: provers, surprisingly, paraphrase, supported, bea, vandals, least, pleistocene,
# Nearest to defense: offense, curt, terrell, lobbyist, defenses, personnel, throws, bureau,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8234 0.0684 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8911 0.0677 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8547 0.0676 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8494 0.0679 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8779 0.0676 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8512 0.0680 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8408 0.0678 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8541 0.0674 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8473 0.0681 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8811 0.0670 sec/batch
# Nearest to not: do, but, to, that, some, for, or, the,
# Nearest to to: that, not, the, a, in, of, and, would,
# Nearest to that: it, to, the, not, cannot, had, a, first,
# Nearest to of: the, in, from, and, a, for, an, by,
# Nearest to many: although, as, are, least, columbus, largely, similarities, prefigured,
# Nearest to on: the, in, of, and, a, by, holiday, march,
# Nearest to can: or, shortcut, infantryman, cannot, if, determining, it, oint,
# Nearest to s: the, in, of, was, has, its, two, first,
# Nearest to heavy: metal, torsional, metalworking, tending, widget, melachim, susa, processed,
# Nearest to applications: karlheinz, dostoyevsky, dxf, decommissioning, freedesktop, developers, elementary, application,
# Nearest to hold: down, robes, humid, prominently, umbrella, raises, truths, cornerbacks,
# Nearest to something: anything, philosophy, insisted, constellations, pleasant, blatantly, unseemly, lunches,
# Nearest to writers: novelists, alumni, essayists, poets, fiction, satirists, births, authors,
# Nearest to report: reports, journal, overview, sofa, summary, forecasts, indepth, apology,
# Nearest to accepted: provers, surprisingly, supported, paraphrase, vandals, bea, pleistocene, least,
# Nearest to defense: offense, curt, lobbyist, terrell, bureau, contras, personnel, defenses,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8509 0.0686 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8521 0.0685 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8518 0.0690 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8423 0.0680 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8945 0.0686 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8320 0.0676 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9484 0.0679 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8739 0.0678 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9075 0.0677 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8121 0.0678 sec/batch
# Nearest to not: do, that, but, to, for, be, some, or,
# Nearest to to: that, the, not, a, and, would, in, with,
# Nearest to that: not, to, it, cannot, the, he, had, a,
# Nearest to of: the, in, from, and, for, a, an, s,
# Nearest to many: although, as, are, various, least, largely, developed, voodoo,
# Nearest to on: the, in, of, by, and, march, holiday, a,
# Nearest to can: infantryman, if, or, shortcut, prickly, overwriting, away, fondness,
# Nearest to s: the, in, of, has, was, at, its, but,
# Nearest to heavy: metal, torsional, metalworking, tending, chaplain, abandoning, lyrically, widget,
# Nearest to applications: karlheinz, dostoyevsky, dxf, freedesktop, decommissioning, application, developers, technologies,
# Nearest to hold: down, robes, humid, umbrella, truths, subterfuge, cornerbacks, saadia,
# Nearest to something: anything, what, blatantly, insisted, pleasant, despised, unseemly, philosophy,
# Nearest to writers: novelists, alumni, essayists, poets, fiction, births, satirists, authors,
# Nearest to report: reports, journal, overview, sofa, summary, apology, un, indepth,
# Nearest to accepted: provers, supported, surprisingly, bea, similarities, pleistocene, vandals, paraphrase,
# Nearest to defense: offense, curt, lobbyist, personnel, bureau, terrell, contras, jury,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8023 0.0682 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8655 0.0674 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7931 0.0682 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8897 0.0675 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8322 0.0678 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8570 0.0680 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8486 0.0451 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8365 0.0677 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8075 0.0672 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8614 0.0673 sec/batch
# Nearest to not: that, do, to, or, but, be, some, for,
# Nearest to to: that, not, a, the, in, of, before, when,
# Nearest to that: to, not, it, the, a, cannot, he, in,
# Nearest to of: the, in, and, from, a, for, an, by,
# Nearest to many: although, as, least, are, developed, various, prefigured, largely,
# Nearest to on: the, in, of, a, and, by, to, august,
# Nearest to can: or, unlike, if, shortcut, tailed, to, are, prickly,
# Nearest to s: the, in, of, has, but, a, its, at,
# Nearest to heavy: metal, torsional, metalworking, tending, propelled, widget, metallica, melachim,
# Nearest to applications: karlheinz, dostoyevsky, dxf, decommissioning, freedesktop, developers, application, borderland,
# Nearest to hold: down, truths, robes, humid, saadia, umbrella, subterfuge, foils,
# Nearest to something: anything, despised, blatantly, unseemly, insisted, what, philosophy, ques,
# Nearest to writers: novelists, alumni, essayists, poets, fiction, satirists, births, deaths,
# Nearest to report: journal, reports, sofa, overview, apology, morea, summary, indepth,
# Nearest to accepted: provers, supported, surprisingly, bea, paraphrase, vandals, pleistocene, similarities,
# Nearest to defense: offense, curt, lobbyist, terrell, defenses, personnel, prevents, mixolydian,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8149 0.0686 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8259 0.0673 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8251 0.0675 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8280 0.0671 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8694 0.0672 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8201 0.0677 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8898 0.0681 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7021 0.0683 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8223 0.0688 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7849 0.0685 sec/batch
# Nearest to not: do, that, to, but, for, be, or, some,
# Nearest to to: that, and, not, a, in, the, of, with,
# Nearest to that: to, it, not, the, a, cannot, in, is,
# Nearest to of: the, in, and, from, a, for, an, also,
# Nearest to many: although, as, are, least, various, prefigured, some, developed,
# Nearest to on: the, in, a, of, and, to, by, april,
# Nearest to can: if, or, a, to, shortcut, cannot, are, infantryman,
# Nearest to s: the, in, has, of, its, at, but, two,
# Nearest to heavy: metal, torsional, propelled, metalworking, widget, melachim, tending, susa,
# Nearest to applications: karlheinz, dxf, dostoyevsky, decommissioning, freedesktop, application, gayle, developers,
# Nearest to hold: down, cornerbacks, robes, humid, truths, always, umbrella, raises,
# Nearest to something: anything, unseemly, despised, insisted, blatantly, ques, philosophy, constellations,
# Nearest to writers: novelists, alumni, essayists, poets, satirists, fiction, births, authors,
# Nearest to report: journal, reports, sofa, overview, summary, indepth, morea, lla,
# Nearest to accepted: provers, supported, surprisingly, bea, pleistocene, paraphrase, similarities, beth,
# Nearest to defense: offense, curt, lobbyist, defenses, terrell, mixolydian, personnel, dhyana,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7707 0.0691 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8181 0.0683 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8468 0.0679 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8196 0.0684 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8071 0.0684 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9115 0.0672 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8340 0.0681 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8045 0.0679 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8445 0.0684 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8218 0.0677 sec/batch
# Nearest to not: do, to, that, but, some, or, be, for,
# Nearest to to: that, not, a, the, and, in, of, before,
# Nearest to that: to, it, the, not, a, cannot, is, then,
# Nearest to of: the, in, from, and, a, for, an, also,
# Nearest to many: although, as, are, least, some, these, examples, various,
# Nearest to on: the, in, a, of, by, and, to, when,
# Nearest to can: if, or, shortcut, it, revere, cannot, a, to,
# Nearest to s: the, in, of, has, its, two, was, a,
# Nearest to heavy: metal, torsional, metalworking, widget, melachim, propelled, chaplain, susa,
# Nearest to applications: karlheinz, dostoyevsky, dxf, decommissioning, freedesktop, identify, application, gayle,
# Nearest to hold: down, cornerbacks, humid, robes, always, truths, raises, umbrella,
# Nearest to something: anything, unseemly, insisted, despised, philosophy, blatantly, what, inverts,
# Nearest to writers: novelists, alumni, essayists, poets, fiction, births, satirists, deaths,
# Nearest to report: reports, journal, sofa, overview, indepth, summary, forecasts, lla,
# Nearest to accepted: provers, supported, surprisingly, bea, mop, scientific, balloons, pleistocene,
# Nearest to defense: offense, curt, lobbyist, personnel, defenses, terrell, dhyana, bureau,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8512 0.0688 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8788 0.0670 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8484 0.0680 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8332 0.0673 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8643 0.0677 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8682 0.0677 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8082 0.0675 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8507 0.0681 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8013 0.0685 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8270 0.0680 sec/batch
# Nearest to not: do, that, to, but, or, be, some, for,
# Nearest to to: that, the, not, a, and, in, of, where,
# Nearest to that: not, it, to, the, a, cannot, in, is,
# Nearest to of: the, in, and, from, a, for, an, is,
# Nearest to many: although, as, are, least, developed, but, these, some,
# Nearest to on: the, in, of, a, by, and, to, from,
# Nearest to can: or, if, a, shortcut, it, to, prickly, infantryman,
# Nearest to s: the, in, of, its, has, two, zero, eight,
# Nearest to heavy: metal, metalworking, torsional, melachim, widget, propelled, lyrically, metallica,
# Nearest to applications: karlheinz, dostoyevsky, dxf, decommissioning, freedesktop, phraseology, developers, technologies,
# Nearest to hold: down, humid, saadia, robes, cornerbacks, montenegrins, truths, raises,
# Nearest to something: anything, insisted, unseemly, despised, solipsism, what, ques, blatantly,
# Nearest to writers: novelists, alumni, essayists, poets, fiction, births, deaths, authors,
# Nearest to report: reports, journal, sofa, overview, summary, forecasts, lla, indepth,
# Nearest to accepted: provers, supported, surprisingly, scientific, mop, bea, researching, paraphrase,
# Nearest to defense: offense, curt, lobbyist, personnel, dhyana, bureau, mixolydian, contras,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8535 0.0695 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8162 0.0685 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9345 0.0674 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8899 0.0679 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8948 0.0677 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.7995 0.0678 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7976 0.0675 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8289 0.0675 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7370 0.0681 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8336 0.0679 sec/batch
# Nearest to not: do, that, to, be, but, or, some, for,
# Nearest to to: that, a, not, in, the, of, and, where,
# Nearest to that: not, to, it, a, the, cannot, in, is,
# Nearest to of: the, in, and, from, a, for, an, s,
# Nearest to many: although, as, are, developed, some, various, such, prefigured,
# Nearest to on: the, in, of, a, and, by, s, to,
# Nearest to can: or, if, a, is, are, to, shortcut, prickly,
# Nearest to s: the, in, of, has, two, a, zero, was,
# Nearest to heavy: metal, torsional, propelled, chaplain, metalworking, gianfranco, tending, melachim,
# Nearest to applications: karlheinz, dostoyevsky, dxf, freedesktop, decommissioning, developers, scripting, application,
# Nearest to hold: truths, humid, down, cornerbacks, montenegrins, raises, saadia, umbrella,
# Nearest to something: anything, despised, insisted, unseemly, what, ques, think, blatantly,
# Nearest to writers: novelists, alumni, essayists, poets, fiction, births, deaths, authors,
# Nearest to report: reports, sofa, journal, muslims, overview, summary, forecasts, lla,
# Nearest to accepted: provers, supported, surprisingly, bea, mop, scientific, pleistocene, researching,
# Nearest to defense: offense, curt, lobbyist, dhyana, personnel, bureau, contras, mixolydian,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8289 0.0685 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8229 0.0674 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
